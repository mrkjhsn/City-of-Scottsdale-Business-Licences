# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

business_licenses = pd.read_csv('BusinessLicenses_cleaned.txt', sep='|', engine='python')

plt.rcParams["figure.figsize"] = [15, 7]    #sets the ploted size
plt.title("Scottsdale Business License Numbers Issued Over Time",fontsize=20)
plt.xlabel("Count of Licenses",fontsize=14)
plt.ylabel("License Number",fontsize=14)

y = business_licenses.sort_values(['LicenseNumber'], ascending=[1]).loc[:,'LicenseNumber'] #slices only data in specific column
x = business_licenses.index  #graphs y against number of rows of data
plt.plot(x,y)

# %%
#to look at - fine grained shapes of business license numbers graphed, e.g. the oldest 1000 businesses
plt.rcParams["figure.figsize"] = [15, 7]    #sets the ploted size
plt.title("Scottsdale Business License Numbers Issued Over Time",fontsize=20)
plt.xlabel("Count of Licenses",fontsize=14)
plt.ylabel("License Number",fontsize=14)


plt.ylim(0, 30000) #examine just business numbers under 2000
plt.xlim(0, 500)

y = business_licenses.sort_values(['LicenseNumber'], ascending=[1]).loc[:,'LicenseNumber'] #slices only data in specific column
x = business_licenses.index  #graphs y against number of rows of data
print(y).head()
plt.plot(x,y)
# Out:
# 21690     27
# 10381    168
# 11045    206
# 2447     211
# 23568    285
# Name: LicenseNumber, dtype: int64
